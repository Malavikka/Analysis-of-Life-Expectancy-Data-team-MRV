# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('Normalized_data.csv')

# %%
corr = df.corr()
corr.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_31ee0424_ed53_11e8_a92e_496edc04f8b3row0_col0 {
#             background-color:  #023858;
#         }    #T_31ee0424_ed53_11e8_a92e_496edc04f8b3row0_col1 {
#             background-color:  #ede8f3;
#         }    #T_31ee0424_ed53_11e8_a92e_496edc04f8b3row0_col2 {
#             background-color:  #9cb9d9;
#         }    #T_31ee0424_ed53_11e8_a92e_496edc04f8b3row0_col3 {
#             background-color:  #8fb4d6;
#         }    #T_31ee0424_ed53_11e8_a92e_496edc04f8b3row0_col4 {
#             background-color:  #e4e1ef;
#         }    #T_31ee0424_ed53_11e8_a92e_496edc04f8b3row0_col5 {
#             background-color:  #ced0e6;
#         }    #T_31ee0424_ed53_11e8_a92e_496edc04f8b3row0_col6 {
#             background-color:  #e0deed;
#         }    #T_31ee0424_ed53_11e8_a92e_496edc04f8b3row0_col7 {
#             background-color:  #e1dfed;
#         }    #T_31ee0424_ed53_11e8_a92e_496edc04f8b3row0_col8 {
#             background-color:  #ebe6f2;
# ...

# %%
import numpy as np
from scipy.stats import norm, pareto, kstest
import pandas as pd
import random
from scipy import stats

# %%
df = pd.read_csv('Normalized_data.csv')
df
# Out:
#       Unnamed: 0      Country  Year      Status  Life_expectancy   \
# 0              0  Afghanistan  2015  Developing         -0.444372
# 1              1  Afghanistan  2014  Developing         -0.980783
# 2              2  Afghanistan  2013  Developing         -0.980783
# 3              3  Afghanistan  2012  Developing         -1.022854
# 4              4  Afghanistan  2011  Developing         -1.054408
# 5              5  Afghanistan  2010  Developing         -1.096479
# 6              6  Afghanistan  2009  Developing         -1.117515
# 7              7  Afghanistan  2008  Developing         -1.170104
# 8              8  Afghanistan  2007  Developing         -1.233212
# 9              9  Afghanistan  2006  Developing         -1.254247
# 10            10  Afghanistan  2005  Developing         -1.254247
# 11            11  Afghanistan  2004  Developing         -1.285801
# 12            12  Afghanistan  2003  Developing         -1.317354
# ...

# %%
stats.norm.cdf(-0.210999803300243, df['Measles '].mean(), df['Measles '].std())
# Out:
# 0.4164437124218758

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import pylab as pl
import pandas as pd

# %%
data=pd.read_csv('Life_Expectancy_Data.csv')

# %%
data=data.loc[data['Country']=='India']
df = data.iloc[:,[1,3,4,5,8,9,10]]

# %%
data_to_plot = pd.DataFrame(
    {'Infant_Death': infant_deaths,
     'Polio': polio,
     'Year':[2015,2014,2013,2012,2011,2010,2009,2008,2007,2006,2005,2004,2003,2002,2001,2000]
    })
data_to_plot.plot(x='Year',y=['Infant_Death','Polio'])
plt.ylabel('No of occurrences')
# Out:
# Text(0,0.5,'No of occurrences')

# %%
# Out:
# Text(0,0.5,'No of occurrences')

# %%
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Country, Year, Status, Life_expectancy , Adult Mortality, infant_deaths, Alcohol, percentage_expenditure, Hepatitis_B, Measles ,  BMI , under_five_deaths , Polio, Total expenditure, Diphtheria ,  HIV/AIDS, GDP, Population,  Thinness_1-19_years,  thinness_5-9_years, Income_composition_of_resources, Schooling]
# Index: []
#
# [0 rows x 23 columns]
